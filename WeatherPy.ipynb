# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 603

# %%
# 1. Import our dependencies and initialize counters and an empty list that will hold the weather data.

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# Import the datetime module from the datetime library.
from datetime import datetime

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2ec4810455348a34f43d1ba06520da36

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# 2. Loop through the cities list.
# 3. Group the cities in sets of 50 to log the process as we find the weather data for each city.
    # Two counters will be needed here: one to log the city count from 1 to 50, and another for the sets.
# 4. Build the city_url or endpoint for each city.
# 5. Log the URL and the record and set numbers.

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1

# 6. Make an API request for each city.
# 7.Parse the JSON weather data for the following:
    # City, country, and date
    # Latitude and longitude
    # Maximum temperature
    # Humidity
    # Cloudiness
    # Wind speed
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | castro
# Processing Record 2 of Set 1 | solnechnyy
# Processing Record 3 of Set 1 | faanui
# Processing Record 4 of Set 1 | mayumba
# Processing Record 5 of Set 1 | jamestown
# Processing Record 6 of Set 1 | grand gaube
# Processing Record 7 of Set 1 | bambous virieux
# Processing Record 8 of Set 1 | hermanus
# Processing Record 9 of Set 1 | caravelas
# Processing Record 10 of Set 1 | puerto ayacucho
# Processing Record 11 of Set 1 | rikitea
# Processing Record 12 of Set 1 | narsaq
# Processing Record 13 of Set 1 | neiafu
# Processing Record 14 of Set 1 | vaini
# Processing Record 15 of Set 1 | lata
# Processing Record 16 of Set 1 | bluff
# Processing Record 17 of Set 1 | shache
# Processing Record 18 of Set 1 | padang
# Processing Record 19 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 20 of Set 1 | jumla
# Processing Record 21 of Set 1 | salalah
# Processing Record 22 of Set 1 | alta floresta
# Processing Record 23 of Set 1 | kapaa
# Processing Record 24 of Set 1 | hun
# Processing Record 25 of Set 1 | mys shmidta
# City not found. Skipping...
# Processing Record 26 of Set 1 | flagstaff
# Processing Record 27 of Set 1 | punta arenas
# Processing Record 28 of Set 1 | nanning
# Processing Record 29 of Set 1 | nemuro
# Processing Record 30 of Set 1 | ushuaia
# Processing Record 31 of Set 1 | pevek
# Processing Record 32 of Set 1 | kendari
# Processing Record 33 of Set 1 | hobart
# Processing Record 34 of Set 1 | nome
# Processing Record 35 of Set 1 | barrow
# Processing Record 36 of Set 1 | hithadhoo
# Processing Record 37 of Set 1 | thompson
# Processing Record 38 of Set 1 | iberia
# Processing Record 39 of Set 1 | luleburgaz
# Processing Record 40 of Set 1 | grand river south east
# City not found. Skipping...
# Processing Record 41 of Set 1 | ziarat
# Processing Record 42 of Set 1 | panama city
# Processing Record 43 of Set 1 | rawson
# Processing Record 44 of Set 1 | yegorlykskaya
# Processing Record 45 of Set 1 | preobrazheniye
# Processing Record 46 of Set 1 | coquimbo
# Processing Record 47 of Set 1 | orikum
# Processing Record 48 of Set 1 | marcona
# City not found. Skipping...
# Processing Record 49 of Set 1 | biga
# Processing Record 50 of Set 1 | vila franca do campo
# Processing Record 1 of Set 2 | airai
# Processing Record 2 of Set 2 | ponta do sol
# Processing Record 3 of Set 2 | torbay
# Processing Record 4 of Set 2 | nguiu
# City not found. Skipping...
# Processing Record 5 of Set 2 | busselton
# Processing Record 6 of Set 2 | cape town
# Processing Record 7 of Set 2 | smalininkai
# Processing Record 8 of Set 2 | americus
# Processing Record 9 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 10 of Set 2 | mount gambier
# Processing Record 11 of Set 2 | leningradskiy
# Processing Record 12 of Set 2 | hilo
# Processing Record 13 of Set 2 | letlhakeng
# Processing Record 14 of Set 2 | tuktoyaktuk
# Processing Record 15 of Set 2 | bellefontaine
# Processing Record 16 of Set 2 | petropavlovsk-kamchatskiy
# Processing Record 17 of Set 2 | sao filipe
# Processing Record 18 of Set 2 | ribeira grande
# Processing Record 19 of Set 2 | severo-kurilsk
# Processing Record 20 of Set 2 | biak
# Processing Record 21 of Set 2 | mar del plata
# Processing Record 22 of Set 2 | port alfred
# Processing Record 23 of Set 2 | bathsheba
# Processing Record 24 of Set 2 | provideniya
# Processing Record 25 of Set 2 | yellowknife
# Processing Record 26 of Set 2 | subacius
# City not found. Skipping...
# Processing Record 27 of Set 2 | iqaluit
# Processing Record 28 of Set 2 | bolivar
# Processing Record 29 of Set 2 | yurty
# Processing Record 30 of Set 2 | saint george
# Processing Record 31 of Set 2 | whitefish
# Processing Record 32 of Set 2 | miramar
# Processing Record 33 of Set 2 | farkhor
# Processing Record 34 of Set 2 | mtwara
# Processing Record 35 of Set 2 | svetlyy
# Processing Record 36 of Set 2 | kavaratti
# Processing Record 37 of Set 2 | avarua
# Processing Record 38 of Set 2 | stephenville
# Processing Record 39 of Set 2 | grand forks
# Processing Record 40 of Set 2 | puerto ayora
# Processing Record 41 of Set 2 | casper
# Processing Record 42 of Set 2 | cabo san lucas
# Processing Record 43 of Set 2 | ahumada
# City not found. Skipping...
# Processing Record 44 of Set 2 | skalistyy
# City not found. Skipping...
# Processing Record 45 of Set 2 | port elizabeth
# Processing Record 46 of Set 2 | kapit
# Processing Record 47 of Set 2 | acapulco
# Processing Record 48 of Set 2 | kattivakkam
# Processing Record 49 of Set 2 | ahipara
# Processing Record 50 of Set 2 | rantepao
# Processing Record 1 of Set 3 | khatanga
# Processing Record 2 of Set 3 | margate
# Processing Record 3 of Set 3 | carnarvon
# Processing Record 4 of Set 3 | atar
# Processing Record 5 of Set 3 | mega
# Processing Record 6 of Set 3 | chuy
# Processing Record 7 of Set 3 | fortuna
# Processing Record 8 of Set 3 | mataura
# Processing Record 9 of Set 3 | kedgwick
# Processing Record 10 of Set 3 | zhigansk
# Processing Record 11 of Set 3 | kangaatsiaq
# Processing Record 12 of Set 3 | clyde river
# Processing Record 13 of Set 3 | vao
# Processing Record 14 of Set 3 | qaanaaq
# Processing Record 15 of Set 3 | mahebourg
# Processing Record 16 of Set 3 | pangnirtung
# Processing Record 17 of Set 3 | jiangyou
# Processing Record 18 of Set 3 | atuona
# Processing Record 19 of Set 3 | acari
# Processing Record 20 of Set 3 | one hundred mile house
# City not found. Skipping...
# Processing Record 21 of Set 3 | ende
# Processing Record 22 of Set 3 | loreto
# Processing Record 23 of Set 3 | cockburn town
# Processing Record 24 of Set 3 | lorengau
# Processing Record 25 of Set 3 | kaitangata
# Processing Record 26 of Set 3 | lebu
# Processing Record 27 of Set 3 | bethel
# Processing Record 28 of Set 3 | guerrero negro
# Processing Record 29 of Set 3 | mayo
# Processing Record 30 of Set 3 | gurskoye
# City not found. Skipping...
# Processing Record 31 of Set 3 | college
# Processing Record 32 of Set 3 | camana
# Processing Record 33 of Set 3 | mauguio
# Processing Record 34 of Set 3 | marzuq
# Processing Record 35 of Set 3 | lavrentiya
# Processing Record 36 of Set 3 | tasiilaq
# Processing Record 37 of Set 3 | sioux lookout
# Processing Record 38 of Set 3 | lisala
# Processing Record 39 of Set 3 | mendahara
# City not found. Skipping...
# Processing Record 40 of Set 3 | sorong
# Processing Record 41 of Set 3 | albany
# Processing Record 42 of Set 3 | east london
# Processing Record 43 of Set 3 | bardiyah
# Processing Record 44 of Set 3 | newport
# Processing Record 45 of Set 3 | gat
# Processing Record 46 of Set 3 | saskylakh
# Processing Record 47 of Set 3 | esperance
# Processing Record 48 of Set 3 | quatre cocos
# Processing Record 49 of Set 3 | alice
# Processing Record 50 of Set 3 | honiara
# Processing Record 1 of Set 4 | progreso
# Processing Record 2 of Set 4 | adrar
# Processing Record 3 of Set 4 | bolungarvik
# City not found. Skipping...
# Processing Record 4 of Set 4 | khandyga
# Processing Record 5 of Set 4 | cidreira
# Processing Record 6 of Set 4 | kharp
# Processing Record 7 of Set 4 | turukhansk
# Processing Record 8 of Set 4 | new norfolk
# Processing Record 9 of Set 4 | kieta
# Processing Record 10 of Set 4 | ryde
# Processing Record 11 of Set 4 | bredasdorp
# Processing Record 12 of Set 4 | vila velha
# Processing Record 13 of Set 4 | indianola
# Processing Record 14 of Set 4 | norman wells
# Processing Record 15 of Set 4 | saint-augustin
# Processing Record 16 of Set 4 | port hedland
# Processing Record 17 of Set 4 | khor
# Processing Record 18 of Set 4 | ewo
# Processing Record 19 of Set 4 | naze
# Processing Record 20 of Set 4 | bom jardim
# Processing Record 21 of Set 4 | matay
# Processing Record 22 of Set 4 | muggia
# Processing Record 23 of Set 4 | kurilsk
# Processing Record 24 of Set 4 | te anau
# Processing Record 25 of Set 4 | dikson
# Processing Record 26 of Set 4 | eresos
# Processing Record 27 of Set 4 | tateyama
# Processing Record 28 of Set 4 | asau
# Processing Record 29 of Set 4 | pemangkat
# Processing Record 30 of Set 4 | vinukonda
# Processing Record 31 of Set 4 | tallahassee
# Processing Record 32 of Set 4 | tabukiniberu
# City not found. Skipping...
# Processing Record 33 of Set 4 | hay river
# Processing Record 34 of Set 4 | diamantino
# Processing Record 35 of Set 4 | maghama
# City not found. Skipping...
# Processing Record 36 of Set 4 | shinjo
# Processing Record 37 of Set 4 | grindavik
# Processing Record 38 of Set 4 | chokurdakh
# Processing Record 39 of Set 4 | charters towers
# Processing Record 40 of Set 4 | paamiut
# Processing Record 41 of Set 4 | urusha
# Processing Record 42 of Set 4 | barentsburg
# City not found. Skipping...
# Processing Record 43 of Set 4 | butaritari
# Processing Record 44 of Set 4 | port blair
# Processing Record 45 of Set 4 | kruisfontein
# Processing Record 46 of Set 4 | turayf
# Processing Record 47 of Set 4 | piranshahr
# Processing Record 48 of Set 4 | sao joao da barra
# Processing Record 49 of Set 4 | amderma
# City not found. Skipping...
# Processing Record 50 of Set 4 | metro
# Processing Record 1 of Set 5 | suez
# Processing Record 2 of Set 5 | vaitupu
# City not found. Skipping...
# Processing Record 3 of Set 5 | port macquarie
# Processing Record 4 of Set 5 | oranjemund
# Processing Record 5 of Set 5 | muhos
# Processing Record 6 of Set 5 | victoria
# Processing Record 7 of Set 5 | le port
# Processing Record 8 of Set 5 | sentyabrskiy
# City not found. Skipping...
# Processing Record 9 of Set 5 | arraial do cabo
# Processing Record 10 of Set 5 | nouadhibou
# Processing Record 11 of Set 5 | cooma
# Processing Record 12 of Set 5 | yulara
# Processing Record 13 of Set 5 | westport
# Processing Record 14 of Set 5 | alice springs
# Processing Record 15 of Set 5 | san jose de guanipa
# Processing Record 16 of Set 5 | tura
# Processing Record 17 of Set 5 | bandarbeyla
# Processing Record 18 of Set 5 | mrirt
# City not found. Skipping...
# Processing Record 19 of Set 5 | touros
# Processing Record 20 of Set 5 | geraldton
# Processing Record 21 of Set 5 | luanda
# Processing Record 22 of Set 5 | nizhneyansk
# City not found. Skipping...
# Processing Record 23 of Set 5 | atka
# City not found. Skipping...
# Processing Record 24 of Set 5 | saint-philippe
# Processing Record 25 of Set 5 | safranbolu
# Processing Record 26 of Set 5 | rumonge
# Processing Record 27 of Set 5 | zeya
# Processing Record 28 of Set 5 | owando
# Processing Record 29 of Set 5 | koping
# Processing Record 30 of Set 5 | vizela
# Processing Record 31 of Set 5 | dzhebariki-khaya
# Processing Record 32 of Set 5 | hobyo
# Processing Record 33 of Set 5 | basco
# Processing Record 34 of Set 5 | nikolskoye
# Processing Record 35 of Set 5 | atikokan
# Processing Record 36 of Set 5 | rocha
# Processing Record 37 of Set 5 | tarsus
# Processing Record 38 of Set 5 | jumilla
# Processing Record 39 of Set 5 | jamame
# Processing Record 40 of Set 5 | qaqortoq
# Processing Record 41 of Set 5 | cahors
# Processing Record 42 of Set 5 | kuvandyk
# Processing Record 43 of Set 5 | jussara
# Processing Record 44 of Set 5 | hatillo
# Processing Record 45 of Set 5 | anadyr
# Processing Record 46 of Set 5 | lazaro cardenas
# Processing Record 47 of Set 5 | gueret
# Processing Record 48 of Set 5 | broken hill
# Processing Record 49 of Set 5 | svarstad
# Processing Record 50 of Set 5 | fuldatal
# Processing Record 1 of Set 6 | yuncheng
# Processing Record 2 of Set 6 | gulshat
# City not found. Skipping...
# Processing Record 3 of Set 6 | masuguru
# Processing Record 4 of Set 6 | upernavik
# Processing Record 5 of Set 6 | klaksvik
# Processing Record 6 of Set 6 | darhan
# Processing Record 7 of Set 6 | la ronge
# Processing Record 8 of Set 6 | huajuapan
# City not found. Skipping...
# Processing Record 9 of Set 6 | tecoanapa
# Processing Record 10 of Set 6 | along
# Processing Record 11 of Set 6 | necochea
# Processing Record 12 of Set 6 | kokkola
# Processing Record 13 of Set 6 | baruun-urt
# Processing Record 14 of Set 6 | tiksi
# Processing Record 15 of Set 6 | attawapiskat
# City not found. Skipping...
# Processing Record 16 of Set 6 | punta alta
# Processing Record 17 of Set 6 | lompoc
# Processing Record 18 of Set 6 | atambua
# Processing Record 19 of Set 6 | port hardy
# Processing Record 20 of Set 6 | tawnat
# City not found. Skipping...
# Processing Record 21 of Set 6 | rumford
# Processing Record 22 of Set 6 | faya
# Processing Record 23 of Set 6 | kandrian
# Processing Record 24 of Set 6 | laguna
# Processing Record 25 of Set 6 | seoul
# Processing Record 26 of Set 6 | half moon bay
# Processing Record 27 of Set 6 | yuzhnyy
# Processing Record 28 of Set 6 | henties bay
# Processing Record 29 of Set 6 | tezu
# Processing Record 30 of Set 6 | tuatapere
# Processing Record 31 of Set 6 | key west
# Processing Record 32 of Set 6 | cayenne
# Processing Record 33 of Set 6 | partizanskoye
# Processing Record 34 of Set 6 | karratha
# Processing Record 35 of Set 6 | saleaula
# City not found. Skipping...
# Processing Record 36 of Set 6 | tsihombe
# City not found. Skipping...
# Processing Record 37 of Set 6 | yerbogachen
# Processing Record 38 of Set 6 | olafsvik
# Processing Record 39 of Set 6 | les cayes
# Processing Record 40 of Set 6 | burica
# City not found. Skipping...
# Processing Record 41 of Set 6 | orbetello
# Processing Record 42 of Set 6 | barbar
# City not found. Skipping...
# Processing Record 43 of Set 6 | jabiru
# City not found. Skipping...
# Processing Record 44 of Set 6 | gravdal
# Processing Record 45 of Set 6 | haines junction
# Processing Record 46 of Set 6 | cherskiy
# Processing Record 47 of Set 6 | ust-tsilma
# Processing Record 48 of Set 6 | osakarovka
# Processing Record 49 of Set 6 | manicore
# Processing Record 50 of Set 6 | bagdarin
# Processing Record 1 of Set 7 | holme
# Processing Record 2 of Set 7 | luderitz
# Processing Record 3 of Set 7 | lerwick
# Processing Record 4 of Set 7 | plettenberg bay
# Processing Record 5 of Set 7 | eureka
# Processing Record 6 of Set 7 | ust-kut
# Processing Record 7 of Set 7 | bima
# Processing Record 8 of Set 7 | burnie
# Processing Record 9 of Set 7 | georgetown
# Processing Record 10 of Set 7 | pisco
# Processing Record 11 of Set 7 | ibotirama
# Processing Record 12 of Set 7 | kodiak
# Processing Record 13 of Set 7 | salamiyah
# Processing Record 14 of Set 7 | jibuti
# Processing Record 15 of Set 7 | vanavara
# Processing Record 16 of Set 7 | broome
# Processing Record 17 of Set 7 | makung
# City not found. Skipping...
# Processing Record 18 of Set 7 | conakry
# Processing Record 19 of Set 7 | morehead
# Processing Record 20 of Set 7 | fort nelson
# Processing Record 21 of Set 7 | shubarshi
# Processing Record 22 of Set 7 | dingle
# Processing Record 23 of Set 7 | sinnamary
# Processing Record 24 of Set 7 | uroteppa
# City not found. Skipping...
# Processing Record 25 of Set 7 | samusu
# City not found. Skipping...
# Processing Record 26 of Set 7 | constitucion
# Processing Record 27 of Set 7 | abeche
# Processing Record 28 of Set 7 | palabuhanratu
# City not found. Skipping...
# Processing Record 29 of Set 7 | leh
# Processing Record 30 of Set 7 | saint-leu
# Processing Record 31 of Set 7 | vasilyevskiy mokh
# Processing Record 32 of Set 7 | smithers
# Processing Record 33 of Set 7 | talnakh
# Processing Record 34 of Set 7 | bereda
# Processing Record 35 of Set 7 | shimoda
# Processing Record 36 of Set 7 | marsh harbour
# Processing Record 37 of Set 7 | coari
# Processing Record 38 of Set 7 | altamont
# Processing Record 39 of Set 7 | usvyaty
# Processing Record 40 of Set 7 | okhotsk
# Processing Record 41 of Set 7 | marang
# Processing Record 42 of Set 7 | khasan
# Processing Record 43 of Set 7 | lufilufi
# Processing Record 44 of Set 7 | spartanburg
# Processing Record 45 of Set 7 | shubarkuduk
# Processing Record 46 of Set 7 | tafresh
# Processing Record 47 of Set 7 | bonoua
# Processing Record 48 of Set 7 | kasongo-lunda
# Processing Record 49 of Set 7 | hays
# Processing Record 50 of Set 7 | barcelona
# Processing Record 1 of Set 8 | ilulissat
# Processing Record 2 of Set 8 | matara
# Processing Record 3 of Set 8 | galesong
# Processing Record 4 of Set 8 | mustafakemalpasa
# Processing Record 5 of Set 8 | laya
# Processing Record 6 of Set 8 | carora
# Processing Record 7 of Set 8 | svetlogorsk
# Processing Record 8 of Set 8 | yeppoon
# Processing Record 9 of Set 8 | huarmey
# Processing Record 10 of Set 8 | saldanha
# Processing Record 11 of Set 8 | lagos
# Processing Record 12 of Set 8 | sitka
# Processing Record 13 of Set 8 | sai buri
# Processing Record 14 of Set 8 | kostomuksha
# Processing Record 15 of Set 8 | ussel
# Processing Record 16 of Set 8 | mocambique
# City not found. Skipping...
# Processing Record 17 of Set 8 | vangaindrano
# Processing Record 18 of Set 8 | pudozh
# Processing Record 19 of Set 8 | khalkoutsion
# Processing Record 20 of Set 8 | tacuarembo
# Processing Record 21 of Set 8 | umzimvubu
# City not found. Skipping...
# Processing Record 22 of Set 8 | hofn
# Processing Record 23 of Set 8 | dicabisagan
# Processing Record 24 of Set 8 | ribas do rio pardo
# Processing Record 25 of Set 8 | ancud
# Processing Record 26 of Set 8 | ulaanbaatar
# Processing Record 27 of Set 8 | shakhovskaya
# Processing Record 28 of Set 8 | severobaykalsk
# Processing Record 29 of Set 8 | ormara
# Processing Record 30 of Set 8 | huangnihe
# Processing Record 31 of Set 8 | kungurtug
# Processing Record 32 of Set 8 | mocuba
# Processing Record 33 of Set 8 | havoysund
# Processing Record 34 of Set 8 | bondo
# Processing Record 35 of Set 8 | providencia
# Processing Record 36 of Set 8 | saint anthony
# Processing Record 37 of Set 8 | inirida
# Processing Record 38 of Set 8 | bauru
# Processing Record 39 of Set 8 | khonuu
# City not found. Skipping...
# Processing Record 40 of Set 8 | port keats
# Processing Record 41 of Set 8 | arroyo
# Processing Record 42 of Set 8 | thurso
# Processing Record 43 of Set 8 | buston
# Processing Record 44 of Set 8 | pozo colorado
# Processing Record 45 of Set 8 | sampit
# Processing Record 46 of Set 8 | joensuu
# Processing Record 47 of Set 8 | nanortalik
# Processing Record 48 of Set 8 | belushya guba
# City not found. Skipping...
# Processing Record 49 of Set 8 | taltal
# Processing Record 50 of Set 8 | rio grande
# Processing Record 1 of Set 9 | viedma
# Processing Record 2 of Set 9 | karpathos
# Processing Record 3 of Set 9 | san quintin
# Processing Record 4 of Set 9 | madinat sittah uktubar
# Processing Record 5 of Set 9 | roald
# Processing Record 6 of Set 9 | vila
# Processing Record 7 of Set 9 | isangel
# Processing Record 8 of Set 9 | louisbourg
# City not found. Skipping...
# Processing Record 9 of Set 9 | guangyuan
# Processing Record 10 of Set 9 | mahibadhoo
# Processing Record 11 of Set 9 | nueva granada
# Processing Record 12 of Set 9 | batsfjord
# Processing Record 13 of Set 9 | guaratinga
# Processing Record 14 of Set 9 | saint-francois
# Processing Record 15 of Set 9 | gaspar
# Processing Record 16 of Set 9 | kuytun
# Processing Record 17 of Set 9 | dobsina
# Processing Record 18 of Set 9 | aksarayskiy
# Processing Record 19 of Set 9 | shenkursk
# Processing Record 20 of Set 9 | aklavik
# Processing Record 21 of Set 9 | mehamn
# Processing Record 22 of Set 9 | polovinnoye
# Processing Record 23 of Set 9 | gap
# Processing Record 24 of Set 9 | iskateley
# Processing Record 25 of Set 9 | kavieng
# Processing Record 26 of Set 9 | hailar
# Processing Record 27 of Set 9 | sobolevo
# Processing Record 28 of Set 9 | hingorja
# Processing Record 29 of Set 9 | terrace
# Processing Record 30 of Set 9 | alofi
# Processing Record 31 of Set 9 | ushumun
# Processing Record 32 of Set 9 | nuuk
# Processing Record 33 of Set 9 | ayr
# Processing Record 34 of Set 9 | severodvinsk
# Processing Record 35 of Set 9 | roma
# Processing Record 36 of Set 9 | ossora
# Processing Record 37 of Set 9 | sola
# Processing Record 38 of Set 9 | buchanan
# Processing Record 39 of Set 9 | buariki
# City not found. Skipping...
# Processing Record 40 of Set 9 | gushikawa
# Processing Record 41 of Set 9 | binga
# Processing Record 42 of Set 9 | portland
# Processing Record 43 of Set 9 | longyearbyen
# Processing Record 44 of Set 9 | fajardo
# Processing Record 45 of Set 9 | artyk
# City not found. Skipping...
# Processing Record 46 of Set 9 | adamas
# Processing Record 47 of Set 9 | allonnes
# Processing Record 48 of Set 9 | jijiga
# Processing Record 49 of Set 9 | umm lajj
# Processing Record 50 of Set 9 | autun
# Processing Record 1 of Set 10 | yar-sale
# Processing Record 2 of Set 10 | wiwili
# Processing Record 3 of Set 10 | soe
# Processing Record 4 of Set 10 | kurduvadi
# Processing Record 5 of Set 10 | ukiah
# Processing Record 6 of Set 10 | tyukalinsk
# Processing Record 7 of Set 10 | poum
# Processing Record 8 of Set 10 | mana
# Processing Record 9 of Set 10 | vanimo
# Processing Record 10 of Set 10 | kisanga
# Processing Record 11 of Set 10 | kasane
# Processing Record 12 of Set 10 | havre-saint-pierre
# Processing Record 13 of Set 10 | bilma
# Processing Record 14 of Set 10 | souillac
# Processing Record 15 of Set 10 | enniscorthy
# Processing Record 16 of Set 10 | malakal
# Processing Record 17 of Set 10 | nyrob
# Processing Record 18 of Set 10 | berlevag
# Processing Record 19 of Set 10 | varhaug
# Processing Record 20 of Set 10 | feodosiya
# Processing Record 21 of Set 10 | talcahuano
# Processing Record 22 of Set 10 | ketchikan
# Processing Record 23 of Set 10 | hualmay
# Processing Record 24 of Set 10 | hunucma
# Processing Record 25 of Set 10 | roswell
# Processing Record 26 of Set 10 | macomer
# Processing Record 27 of Set 10 | green valley
# Processing Record 28 of Set 10 | hasaki
# Processing Record 29 of Set 10 | san vicente
# Processing Record 30 of Set 10 | taoudenni
# Processing Record 31 of Set 10 | havelock
# Processing Record 32 of Set 10 | voi
# Processing Record 33 of Set 10 | tabou
# Processing Record 34 of Set 10 | hambantota
# Processing Record 35 of Set 10 | aitape
# Processing Record 36 of Set 10 | longyan
# Processing Record 37 of Set 10 | barawe
# City not found. Skipping...
# Processing Record 38 of Set 10 | belmonte
# Processing Record 39 of Set 10 | jaguariaiva
# Processing Record 40 of Set 10 | laem sing
# Processing Record 41 of Set 10 | praia da vitoria
# Processing Record 42 of Set 10 | dwarka
# Processing Record 43 of Set 10 | beringovskiy
# Processing Record 44 of Set 10 | south lake tahoe
# Processing Record 45 of Set 10 | baindur
# Processing Record 46 of Set 10 | rybnaya sloboda
# Processing Record 47 of Set 10 | tubruq
# City not found. Skipping...
# Processing Record 48 of Set 10 | tarko-sale
# Processing Record 49 of Set 10 | cazaje
# City not found. Skipping...
# Processing Record 50 of Set 10 | ayan
# Processing Record 1 of Set 11 | mantua
# Processing Record 2 of Set 11 | litoral del san juan
# City not found. Skipping...
# Processing Record 3 of Set 11 | teluknaga
# Processing Record 4 of Set 11 | liverpool
# Processing Record 5 of Set 11 | hervey bay
# Processing Record 6 of Set 11 | mahadday weyne
# City not found. Skipping...
# Processing Record 7 of Set 11 | sarahan
# Processing Record 8 of Set 11 | zhangye
# Processing Record 9 of Set 11 | chifeng
# Processing Record 10 of Set 11 | tres passos
# Processing Record 11 of Set 11 | bubaque
# Processing Record 12 of Set 11 | andapa
# Processing Record 13 of Set 11 | ipora
# Processing Record 14 of Set 11 | barvinkove
# Processing Record 15 of Set 11 | japura
# Processing Record 16 of Set 11 | san pedro
# Processing Record 17 of Set 11 | kahului
# Processing Record 18 of Set 11 | gubkinskiy
# Processing Record 19 of Set 11 | davila
# Processing Record 20 of Set 11 | sabang
# Processing Record 21 of Set 11 | gigmoto
# Processing Record 22 of Set 11 | kazachinskoye
# Processing Record 23 of Set 11 | tambacounda
# Processing Record 24 of Set 11 | san patricio
# Processing Record 25 of Set 11 | chara
# Processing Record 26 of Set 11 | sharjah
# Processing Record 27 of Set 11 | nantucket
# Processing Record 28 of Set 11 | andenes
# Processing Record 29 of Set 11 | road town
# Processing Record 30 of Set 11 | dryden
# Processing Record 31 of Set 11 | sibolga
# Processing Record 32 of Set 11 | darnah
# Processing Record 33 of Set 11 | betare oya
# Processing Record 34 of Set 11 | san cristobal
# Processing Record 35 of Set 11 | souris
# Processing Record 36 of Set 11 | hamilton
# Processing Record 37 of Set 11 | machali
# Processing Record 38 of Set 11 | komsomolskiy
# Processing Record 39 of Set 11 | hami
# Processing Record 40 of Set 11 | san policarpo
# Processing Record 41 of Set 11 | espanola
# Processing Record 42 of Set 11 | rio branco
# Processing Record 43 of Set 11 | amambai
# Processing Record 44 of Set 11 | ostersund
# Processing Record 45 of Set 11 | zyryanka
# Processing Record 46 of Set 11 | yenagoa
# Processing Record 47 of Set 11 | camara de lobos
# Processing Record 48 of Set 11 | dharmanagar
# Processing Record 49 of Set 11 | fairbanks
# Processing Record 50 of Set 11 | tilichiki
# Processing Record 1 of Set 12 | yambio
# Processing Record 2 of Set 12 | laramie
# Processing Record 3 of Set 12 | volterra
# Processing Record 4 of Set 12 | lamu
# Processing Record 5 of Set 12 | mathbaria
# Processing Record 6 of Set 12 | marshall
# Processing Record 7 of Set 12 | tumannyy
# City not found. Skipping...
# Processing Record 8 of Set 12 | odweyne
# Processing Record 9 of Set 12 | tucurui
# Processing Record 10 of Set 12 | vila do maio
# Processing Record 11 of Set 12 | harper
# Processing Record 12 of Set 12 | shenjiamen
# Processing Record 13 of Set 12 | santa isabel
# Processing Record 14 of Set 12 | aquiraz
# Processing Record 15 of Set 12 | tilbury
# Processing Record 16 of Set 12 | maniitsoq
# Processing Record 17 of Set 12 | carmen
# Processing Record 18 of Set 12 | riyadh
# Processing Record 19 of Set 12 | puerto del rosario
# Processing Record 20 of Set 12 | kupang
# Processing Record 21 of Set 12 | bengkulu
# Processing Record 22 of Set 12 | crestview
# Processing Record 23 of Set 12 | hirara
# Processing Record 24 of Set 12 | gornopravdinsk
# Processing Record 25 of Set 12 | filadelfia
# Processing Record 26 of Set 12 | bajil
# Processing Record 27 of Set 12 | lodja
# Processing Record 28 of Set 12 | buin
# Processing Record 29 of Set 12 | christchurch
# Processing Record 30 of Set 12 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 31 of Set 12 | port-cartier
# Processing Record 32 of Set 12 | halalo
# City not found. Skipping...
# Processing Record 33 of Set 12 | miraflores
# Processing Record 34 of Set 12 | mkushi
# Processing Record 35 of Set 12 | tecolutla
# Processing Record 36 of Set 12 | meulaboh
# Processing Record 37 of Set 12 | nanhai
# Processing Record 38 of Set 12 | xinyang
# Processing Record 39 of Set 12 | liniere
# City not found. Skipping...
# Processing Record 40 of Set 12 | soto la marina
# Processing Record 41 of Set 12 | karkaralinsk
# City not found. Skipping...
# Processing Record 42 of Set 12 | quepos
# Processing Record 43 of Set 12 | rio gallegos
# Processing Record 44 of Set 12 | ozernovskiy
# Processing Record 45 of Set 12 | obo
# Processing Record 46 of Set 12 | tongliao
# Processing Record 47 of Set 12 | kununurra
# Processing Record 48 of Set 12 | sisimiut
# Processing Record 49 of Set 12 | kalemie
# Processing Record 50 of Set 12 | geylegphug
# City not found. Skipping...
# Processing Record 1 of Set 13 | ngunguru
# Processing Record 2 of Set 13 | nyurba
# Processing Record 3 of Set 13 | evensk
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
#               City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0           Castro -24.7911  -50.0119     53.83        94          96
# 1       Solnechnyy  50.7214  136.6319     62.91        52          42
# 2           Faanui -16.4833 -151.7500     77.54        68          16
# 3          Mayumba  -3.4320   10.6554     76.95        84          68
# 4        Jamestown  42.0970  -79.2353     58.59        95           1
# 5      Grand Gaube -20.0064   57.6608     76.37        62           7
# 6  Bambous Virieux -20.3428   57.7575     76.21        69          40
# 7         Hermanus -34.4187   19.2345     61.57        67          84
# 8        Caravelas -17.7125  -39.2481     70.90        63          98
# 9  Puerto Ayacucho   5.6639  -67.6236     73.38        95         100
#
#    Wind Speed Country                 Date
# 0        5.57      BR  2021-09-25 06:42:32
# 1        5.08      RU  2021-09-25 06:42:32
# 2        5.23      PF  2021-09-25 06:42:32
# 3        0.38      GA  2021-09-25 06:42:33
# 4        1.01      US  2021-09-25 06:42:33
# 5       13.00      MU  2021-09-25 06:42:33
# 6       16.11      MU  2021-09-25 06:42:34
# 7        5.12      ZA  2021-09-25 06:42:34
# 8        7.74      BR  2021-09-25 06:42:34
# 9        2.35      VE  2021-09-25 06:42:35

# %%
city_data_reorder = ["City", "Country", "Date", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed"]
city_data_df=city_data_df[city_data_reorder]

city_data_df.head()
# Out:
#          City Country                 Date      Lat       Lng  Max Temp  \
# 0      Castro      BR  2021-09-25 06:42:32 -24.7911  -50.0119     53.83
# 1  Solnechnyy      RU  2021-09-25 06:42:32  50.7214  136.6319     62.91
# 2      Faanui      PF  2021-09-25 06:42:32 -16.4833 -151.7500     77.54
# 3     Mayumba      GA  2021-09-25 06:42:33  -3.4320   10.6554     76.95
# 4   Jamestown      US  2021-09-25 06:42:33  42.0970  -79.2353     58.59
#
#    Humidity  Cloudiness  Wind Speed
# 0        94          96        5.57
# 1        52          42        5.08
# 2        68          16        5.23
# 3        84          68        0.38
# 4        95           1        1.01

# %%
# Create the output file (CSV).
output_data_file = "weather_data/cities.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")

# %%
# Extract relevant fields from the DF for plotting
lats = city_data_df["Lat"]
max_temps = city_data_df["Max Temp"]
humidity = city_data_df["Humidity"]
cloudiness = city_data_df["Cloudiness"]
wind_speed = city_data_df["Wind Speed"]

# %%
# import time module
import time

# build the scatter plot for latitude vs max temp
plt.scatter(lats,
           max_temps,
           edgecolor="black", linewidths=1, marker="o",
           alpha=0.8, label="Cities")

# Incorporate the other graph properties
plt.title(f"City Latitiude vs. Max Temp" + time.strftime(" %x"))
plt.ylabel("Max Temp (F)")
plt.xlabel("Latitude")
plt.grid(True)

# save the figure
plt.savefig("weather_data/Flig1.png")

# show plot
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
# build the scatter plots for lat vs humidity
plt.scatter(lats,
           humidity,
           edgecolor="black", linewidths=1, marker="o",
           alpha=0.8, label="Cities")

# incorporate the other graph properties
plt.title(f"City Latitude vs Humidity" + time.strftime(" %x"))
plt.ylabel("Humidity(%)")
plt.xlabel("Latitude")
plt.grid(True)
# save fig
plt.savefig("weather_data/Fig2.png")
# show plot
plt.show()

# %%
# build scatter plots for lat vs cloudiness
plt.scatter(lats,
           cloudiness,
           edgecolor="black", linewidths=1, marker="o",
           alpha=0.8, label="Cities")

# incorporate other graph properties
plt.title(f"City Latitude vs Cloudiness (%)" + time.strftime(" %x"))
plt.ylabel("Cloudiness (%)")
plt.xlabel("Latitude")
plt.grid(True)
# save the figure
plt.savefig("weather_data/Fig3.png")
#show plot
plt.show()

# %%
# Build the scatter plots for latitude vs. wind speed.
plt.scatter(lats,
            wind_speed,
            edgecolor="black", linewidths=1, marker="o",
            alpha=0.8, label="Cities")

# Incorporate the other graph properties.
plt.title(f"City Latitude vs. Wind Speed "+ time.strftime("%x"))
plt.ylabel("Wind Speed (mph)")
plt.xlabel("Latitude")
plt.grid(True)
# Save the figure.
plt.savefig("weather_data/Fig4.png")
# Show plot.
plt.show()

# %%
# Create Northern and Southern Hemisphere DataFrames.
northern_hemi_df = city_data_df.loc[(city_data_df["Lat"] >= 0)]
southern_hemi_df = city_data_df.loc[(city_data_df["Lat"] < 0)]

# %%
# import linregress
from scipy.stats import linregress

# create a function to perfrom linear reg on the weather data
# and plot a reg line and equation with the data
def plot_linear_regression(x_values, y_values, title, y_label, text_coordinates):
    
    # run regression on hemisphere weather data
    (slope, intercept, r_value, p_value, std_err) = linregress(x_values, y_values)
    
    # calculate the regression line "y values" from the slope and intercept
    regress_values = x_values * slope +intercept
    # get the equation of the line
    line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(slope,2))
    # create a scatter plot and plot the regression line
    plt.scatter(x_values, y_values)
    plt.plot(x_values, regress_values, "r")
    # annotate the text for the line equation
    plt.annotate(line_eq, text_coordinates, fontsize=15, color="red")
    plt.title(title)
    plt.xlabel("latitude")
    plt.ylabel(y_label)
    plt.show()

# %%
# Linear regression on the Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Max Temp"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Northern Hemisphere \
                        for Maximum Temperature', 'Max Temp',(10,40))

# %%
# Linear regression on the Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Max Temp"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Southern Hemisphere \
                        for Maximum Temperature', 'Max Temp',(-50,90))

# %%
# Linear regression on the Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Humidity"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Northern Hemisphere \
                        for % Humidity', '% Humidity',(40,10))

# %%
# Linear regression on the Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Humidity"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Southern Hemisphere \
                        for % Humidity', '% Humidity',(-50,15))

# %%
# Linear regression on the Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Cloudiness"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Northern Hemisphere \
                        for % Cloudiness', '% Cloudiness',(15,50))

# %%
# Linear regression on the Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Cloudiness"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Southern Hemisphere \
                        for % Cloudiness', '% Cloudiness',(-50,60))

# %%
# Linear regression on the Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Wind Speed"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Northern Hemisphere \
                        for Wind Speed', 'Wind Speed',(35,25))

# %%
# Linear regression on the Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Wind Speed"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Southern Hemisphere \
                        for Wind Speed', 'Wind Speed',(-25,25))

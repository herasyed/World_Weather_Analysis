# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 614

# %%
# 1. Import our dependencies and initialize counters and an empty list that will hold the weather data.

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# Import the datetime module from the datetime library.
from datetime import datetime

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2ec4810455348a34f43d1ba06520da36

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# 2. Loop through the cities list.
# 3. Group the cities in sets of 50 to log the process as we find the weather data for each city.
    # Two counters will be needed here: one to log the city count from 1 to 50, and another for the sets.
# 4. Build the city_url or endpoint for each city.
# 5. Log the URL and the record and set numbers.

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1

# 6. Make an API request for each city.
# 7.Parse the JSON weather data for the following:
    # City, country, and date
    # Latitude and longitude
    # Maximum temperature
    # Humidity
    # Cloudiness
    # Wind speed
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | baiyin
# Processing Record 2 of Set 1 | dikson
# Processing Record 3 of Set 1 | kisangani
# Processing Record 4 of Set 1 | cape town
# Processing Record 5 of Set 1 | coquimbo
# Processing Record 6 of Set 1 | georgetown
# Processing Record 7 of Set 1 | busselton
# Processing Record 8 of Set 1 | balclutha
# Processing Record 9 of Set 1 | attawapiskat
# City not found. Skipping...
# Processing Record 10 of Set 1 | conde
# Processing Record 11 of Set 1 | hilo
# Processing Record 12 of Set 1 | adrar
# Processing Record 13 of Set 1 | sao filipe
# Processing Record 14 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 15 of Set 1 | ushuaia
# Processing Record 16 of Set 1 | mataura
# Processing Record 17 of Set 1 | haines junction
# Processing Record 18 of Set 1 | olafsvik
# Processing Record 19 of Set 1 | hassleholm
# Processing Record 20 of Set 1 | domoni
# Processing Record 21 of Set 1 | wawa
# Processing Record 22 of Set 1 | port alfred
# Processing Record 23 of Set 1 | tuktoyaktuk
# Processing Record 24 of Set 1 | villa de reyes
# Processing Record 25 of Set 1 | sao jose do rio preto
# Processing Record 26 of Set 1 | rio gallegos
# Processing Record 27 of Set 1 | codrington
# Processing Record 28 of Set 1 | yar-sale
# Processing Record 29 of Set 1 | komsomolskiy
# Processing Record 30 of Set 1 | bredasdorp
# Processing Record 31 of Set 1 | punta arenas
# Processing Record 32 of Set 1 | vao
# Processing Record 33 of Set 1 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 34 of Set 1 | havelock
# Processing Record 35 of Set 1 | bluff
# Processing Record 36 of Set 1 | pangnirtung
# Processing Record 37 of Set 1 | anadyr
# Processing Record 38 of Set 1 | rikitea
# Processing Record 39 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 40 of Set 1 | yellowknife
# Processing Record 41 of Set 1 | bambous virieux
# Processing Record 42 of Set 1 | hermanus
# Processing Record 43 of Set 1 | barrow
# Processing Record 44 of Set 1 | qasigiannguit
# Processing Record 45 of Set 1 | east london
# Processing Record 46 of Set 1 | jamestown
# Processing Record 47 of Set 1 | new norfolk
# Processing Record 48 of Set 1 | karpuninskiy
# City not found. Skipping...
# Processing Record 49 of Set 1 | khatanga
# Processing Record 50 of Set 1 | bathsheba
# Processing Record 1 of Set 2 | pavelets
# Processing Record 2 of Set 2 | bobonong
# City not found. Skipping...
# Processing Record 3 of Set 2 | atuona
# Processing Record 4 of Set 2 | kodiak
# Processing Record 5 of Set 2 | petrovsk
# Processing Record 6 of Set 2 | chuy
# Processing Record 7 of Set 2 | lompoc
# Processing Record 8 of Set 2 | victoria
# Processing Record 9 of Set 2 | ixtapa
# Processing Record 10 of Set 2 | mackay
# Processing Record 11 of Set 2 | karachi
# Processing Record 12 of Set 2 | bud
# Processing Record 13 of Set 2 | albany
# Processing Record 14 of Set 2 | geraldton
# Processing Record 15 of Set 2 | kailua
# Processing Record 16 of Set 2 | hobart
# Processing Record 17 of Set 2 | puerto ayora
# Processing Record 18 of Set 2 | kolokani
# Processing Record 19 of Set 2 | lagoa
# Processing Record 20 of Set 2 | faanui
# Processing Record 21 of Set 2 | saskylakh
# Processing Record 22 of Set 2 | severo-kurilsk
# Processing Record 23 of Set 2 | upernavik
# Processing Record 24 of Set 2 | hervey bay
# Processing Record 25 of Set 2 | qaanaaq
# Processing Record 26 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 27 of Set 2 | baykit
# Processing Record 28 of Set 2 | toamasina
# Processing Record 29 of Set 2 | ayan
# Processing Record 30 of Set 2 | alice springs
# Processing Record 31 of Set 2 | lata
# Processing Record 32 of Set 2 | vaini
# Processing Record 33 of Set 2 | kosugi
# Processing Record 34 of Set 2 | ushtobe
# Processing Record 35 of Set 2 | nanortalik
# Processing Record 36 of Set 2 | tabiauea
# City not found. Skipping...
# Processing Record 37 of Set 2 | bengkulu
# Processing Record 38 of Set 2 | butaritari
# Processing Record 39 of Set 2 | sentyabrskiy
# City not found. Skipping...
# Processing Record 40 of Set 2 | lebu
# Processing Record 41 of Set 2 | altay
# Processing Record 42 of Set 2 | alofi
# Processing Record 43 of Set 2 | koster
# Processing Record 44 of Set 2 | pemberton
# Processing Record 45 of Set 2 | athabasca
# Processing Record 46 of Set 2 | kaitangata
# Processing Record 47 of Set 2 | la ronge
# Processing Record 48 of Set 2 | luena
# Processing Record 49 of Set 2 | gubkinskiy
# Processing Record 50 of Set 2 | kapaa
# Processing Record 1 of Set 3 | cayenne
# Processing Record 2 of Set 3 | chokurdakh
# Processing Record 3 of Set 3 | arman
# Processing Record 4 of Set 3 | nouakchott
# Processing Record 5 of Set 3 | airai
# Processing Record 6 of Set 3 | henties bay
# Processing Record 7 of Set 3 | kiruna
# Processing Record 8 of Set 3 | zelenoborskiy
# Processing Record 9 of Set 3 | koslan
# Processing Record 10 of Set 3 | padang
# Processing Record 11 of Set 3 | leningradskiy
# Processing Record 12 of Set 3 | gat
# Processing Record 13 of Set 3 | saint-philippe
# Processing Record 14 of Set 3 | los llanos de aridane
# Processing Record 15 of Set 3 | joshimath
# Processing Record 16 of Set 3 | ashland
# Processing Record 17 of Set 3 | lavrentiya
# Processing Record 18 of Set 3 | birjand
# Processing Record 19 of Set 3 | nikolskoye
# Processing Record 20 of Set 3 | high rock
# Processing Record 21 of Set 3 | cabra
# Processing Record 22 of Set 3 | bentiu
# Processing Record 23 of Set 3 | guerrero negro
# Processing Record 24 of Set 3 | jujuy
# City not found. Skipping...
# Processing Record 25 of Set 3 | san jose
# Processing Record 26 of Set 3 | tiksi
# Processing Record 27 of Set 3 | hithadhoo
# Processing Record 28 of Set 3 | kirakira
# Processing Record 29 of Set 3 | ponnani
# Processing Record 30 of Set 3 | deputatskiy
# Processing Record 31 of Set 3 | artyk
# City not found. Skipping...
# Processing Record 32 of Set 3 | pantai remis
# Processing Record 33 of Set 3 | mar del plata
# Processing Record 34 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 35 of Set 3 | clarksburg
# Processing Record 36 of Set 3 | bolonchen
# City not found. Skipping...
# Processing Record 37 of Set 3 | palmas de monte alto
# Processing Record 38 of Set 3 | samusu
# City not found. Skipping...
# Processing Record 39 of Set 3 | bethel
# Processing Record 40 of Set 3 | conway
# Processing Record 41 of Set 3 | sehithwa
# Processing Record 42 of Set 3 | isangel
# Processing Record 43 of Set 3 | kavieng
# Processing Record 44 of Set 3 | altamira
# Processing Record 45 of Set 3 | barranca
# Processing Record 46 of Set 3 | san quintin
# Processing Record 47 of Set 3 | yerbogachen
# Processing Record 48 of Set 3 | sao felix do xingu
# Processing Record 49 of Set 3 | hasaki
# Processing Record 50 of Set 3 | ribeira grande
# Processing Record 1 of Set 4 | syamzha
# Processing Record 2 of Set 4 | touros
# Processing Record 3 of Set 4 | pirajui
# Processing Record 4 of Set 4 | oranjemund
# Processing Record 5 of Set 4 | maceio
# Processing Record 6 of Set 4 | cidreira
# Processing Record 7 of Set 4 | belmonte
# Processing Record 8 of Set 4 | salalah
# Processing Record 9 of Set 4 | canutama
# Processing Record 10 of Set 4 | talnakh
# Processing Record 11 of Set 4 | hamilton
# Processing Record 12 of Set 4 | pevek
# Processing Record 13 of Set 4 | santo tomas
# Processing Record 14 of Set 4 | angoche
# Processing Record 15 of Set 4 | dunedin
# Processing Record 16 of Set 4 | lakatoro
# Processing Record 17 of Set 4 | saleaula
# City not found. Skipping...
# Processing Record 18 of Set 4 | odweyne
# Processing Record 19 of Set 4 | ponta do sol
# Processing Record 20 of Set 4 | mweka
# Processing Record 21 of Set 4 | middelkerke
# Processing Record 22 of Set 4 | beyneu
# Processing Record 23 of Set 4 | ilulissat
# Processing Record 24 of Set 4 | husavik
# Processing Record 25 of Set 4 | adiake
# Processing Record 26 of Set 4 | sarangani
# Processing Record 27 of Set 4 | castro
# Processing Record 28 of Set 4 | cukai
# Processing Record 29 of Set 4 | souillac
# Processing Record 30 of Set 4 | mandera
# Processing Record 31 of Set 4 | amga
# Processing Record 32 of Set 4 | louis trichardt
# Processing Record 33 of Set 4 | ketchikan
# Processing Record 34 of Set 4 | bolungarvik
# City not found. Skipping...
# Processing Record 35 of Set 4 | berasia
# Processing Record 36 of Set 4 | bodinayakkanur
# Processing Record 37 of Set 4 | rzhaksa
# Processing Record 38 of Set 4 | garowe
# Processing Record 39 of Set 4 | balakhta
# Processing Record 40 of Set 4 | tecoanapa
# Processing Record 41 of Set 4 | pisco
# Processing Record 42 of Set 4 | saldanha
# Processing Record 43 of Set 4 | moussoro
# Processing Record 44 of Set 4 | butembo
# Processing Record 45 of Set 4 | amderma
# City not found. Skipping...
# Processing Record 46 of Set 4 | kyenjojo
# Processing Record 47 of Set 4 | ancud
# Processing Record 48 of Set 4 | kwinana
# Processing Record 49 of Set 4 | doha
# Processing Record 50 of Set 4 | kamenskoye
# City not found. Skipping...
# Processing Record 1 of Set 5 | daxian
# City not found. Skipping...
# Processing Record 2 of Set 5 | qafsah
# City not found. Skipping...
# Processing Record 3 of Set 5 | tura
# Processing Record 4 of Set 5 | laurel
# Processing Record 5 of Set 5 | tsihombe
# City not found. Skipping...
# Processing Record 6 of Set 5 | popondetta
# Processing Record 7 of Set 5 | marawi
# Processing Record 8 of Set 5 | tecpan
# Processing Record 9 of Set 5 | baft
# Processing Record 10 of Set 5 | fort nelson
# Processing Record 11 of Set 5 | pemangkat
# Processing Record 12 of Set 5 | saint george
# Processing Record 13 of Set 5 | maarianhamina
# Processing Record 14 of Set 5 | jumla
# Processing Record 15 of Set 5 | ferme-neuve
# Processing Record 16 of Set 5 | tasiilaq
# Processing Record 17 of Set 5 | mikhaylovka
# Processing Record 18 of Set 5 | sur
# Processing Record 19 of Set 5 | praia
# Processing Record 20 of Set 5 | provideniya
# Processing Record 21 of Set 5 | rio grande
# Processing Record 22 of Set 5 | beringovskiy
# Processing Record 23 of Set 5 | roccastrada
# Processing Record 24 of Set 5 | aklavik
# Processing Record 25 of Set 5 | raudeberg
# Processing Record 26 of Set 5 | lasa
# Processing Record 27 of Set 5 | alyangula
# Processing Record 28 of Set 5 | labutta
# City not found. Skipping...
# Processing Record 29 of Set 5 | lorengau
# Processing Record 30 of Set 5 | luderitz
# Processing Record 31 of Set 5 | bagdarin
# Processing Record 32 of Set 5 | saint-pierre
# Processing Record 33 of Set 5 | waingapu
# Processing Record 34 of Set 5 | vestmanna
# Processing Record 35 of Set 5 | tottori
# Processing Record 36 of Set 5 | mitu
# Processing Record 37 of Set 5 | cherskiy
# Processing Record 38 of Set 5 | half moon bay
# Processing Record 39 of Set 5 | biak
# Processing Record 40 of Set 5 | sug-aksy
# City not found. Skipping...
# Processing Record 41 of Set 5 | mut
# Processing Record 42 of Set 5 | diu
# Processing Record 43 of Set 5 | puerto escondido
# Processing Record 44 of Set 5 | port moresby
# Processing Record 45 of Set 5 | avarua
# Processing Record 46 of Set 5 | pacific grove
# Processing Record 47 of Set 5 | nouadhibou
# Processing Record 48 of Set 5 | kahului
# Processing Record 49 of Set 5 | nedjo
# Processing Record 50 of Set 5 | erzin
# Processing Record 1 of Set 6 | thompson
# Processing Record 2 of Set 6 | marsa matruh
# Processing Record 3 of Set 6 | asfi
# Processing Record 4 of Set 6 | longyearbyen
# Processing Record 5 of Set 6 | mahina
# Processing Record 6 of Set 6 | moindou
# Processing Record 7 of Set 6 | carnarvon
# Processing Record 8 of Set 6 | saint-augustin
# Processing Record 9 of Set 6 | el sauzal
# Processing Record 10 of Set 6 | male
# Processing Record 11 of Set 6 | coalcoman
# City not found. Skipping...
# Processing Record 12 of Set 6 | carutapera
# Processing Record 13 of Set 6 | mana
# Processing Record 14 of Set 6 | galveston
# Processing Record 15 of Set 6 | los andes
# Processing Record 16 of Set 6 | lethem
# Processing Record 17 of Set 6 | kharp
# Processing Record 18 of Set 6 | nichinan
# Processing Record 19 of Set 6 | kainantu
# Processing Record 20 of Set 6 | labuhan
# Processing Record 21 of Set 6 | ternate
# Processing Record 22 of Set 6 | kavos
# Processing Record 23 of Set 6 | kalmunai
# Processing Record 24 of Set 6 | clyde river
# Processing Record 25 of Set 6 | karakendzha
# City not found. Skipping...
# Processing Record 26 of Set 6 | bulgan
# Processing Record 27 of Set 6 | kovur
# Processing Record 28 of Set 6 | dryden
# Processing Record 29 of Set 6 | tanda
# Processing Record 30 of Set 6 | kutum
# Processing Record 31 of Set 6 | koungou
# Processing Record 32 of Set 6 | sitka
# Processing Record 33 of Set 6 | nombre de dios
# Processing Record 34 of Set 6 | port elizabeth
# Processing Record 35 of Set 6 | grand centre
# City not found. Skipping...
# Processing Record 36 of Set 6 | bilma
# Processing Record 37 of Set 6 | kovdor
# Processing Record 38 of Set 6 | pangody
# Processing Record 39 of Set 6 | vila velha
# Processing Record 40 of Set 6 | tunduru
# City not found. Skipping...
# Processing Record 41 of Set 6 | yangjiang
# Processing Record 42 of Set 6 | shelburne
# Processing Record 43 of Set 6 | pyshchug
# Processing Record 44 of Set 6 | san cristobal
# Processing Record 45 of Set 6 | chestermere
# Processing Record 46 of Set 6 | tomatlan
# Processing Record 47 of Set 6 | noumea
# Processing Record 48 of Set 6 | auki
# Processing Record 49 of Set 6 | carahue
# Processing Record 50 of Set 6 | vilhena
# Processing Record 1 of Set 7 | tangshan
# Processing Record 2 of Set 7 | terekli-mekteb
# Processing Record 3 of Set 7 | pemba
# Processing Record 4 of Set 7 | bashtanka
# Processing Record 5 of Set 7 | baruun-urt
# Processing Record 6 of Set 7 | sola
# Processing Record 7 of Set 7 | palabuhanratu
# City not found. Skipping...
# Processing Record 8 of Set 7 | dzhusaly
# City not found. Skipping...
# Processing Record 9 of Set 7 | evensk
# Processing Record 10 of Set 7 | takoradi
# Processing Record 11 of Set 7 | san roque
# Processing Record 12 of Set 7 | arraial do cabo
# Processing Record 13 of Set 7 | tucuman
# Processing Record 14 of Set 7 | esperance
# Processing Record 15 of Set 7 | hobyo
# Processing Record 16 of Set 7 | jinchengjiang
# City not found. Skipping...
# Processing Record 17 of Set 7 | bowen
# Processing Record 18 of Set 7 | sun valley
# Processing Record 19 of Set 7 | san patricio
# Processing Record 20 of Set 7 | torbay
# Processing Record 21 of Set 7 | acajutla
# Processing Record 22 of Set 7 | ipixuna
# Processing Record 23 of Set 7 | gasa
# Processing Record 24 of Set 7 | quatre cocos
# Processing Record 25 of Set 7 | cabo san lucas
# Processing Record 26 of Set 7 | ahuimanu
# Processing Record 27 of Set 7 | stawell
# Processing Record 28 of Set 7 | naze
# Processing Record 29 of Set 7 | pauini
# Processing Record 30 of Set 7 | vaitupu
# City not found. Skipping...
# Processing Record 31 of Set 7 | san andres
# Processing Record 32 of Set 7 | abu samrah
# Processing Record 33 of Set 7 | medicine hat
# Processing Record 34 of Set 7 | nizhneyansk
# City not found. Skipping...
# Processing Record 35 of Set 7 | banda aceh
# Processing Record 36 of Set 7 | fairbanks
# Processing Record 37 of Set 7 | namatanai
# Processing Record 38 of Set 7 | boguchany
# Processing Record 39 of Set 7 | mecca
# Processing Record 40 of Set 7 | itaituba
# Processing Record 41 of Set 7 | hovd
# Processing Record 42 of Set 7 | koundara
# Processing Record 43 of Set 7 | aksu
# Processing Record 44 of Set 7 | sakaiminato
# Processing Record 45 of Set 7 | taoudenni
# Processing Record 46 of Set 7 | riyadh
# Processing Record 47 of Set 7 | buala
# Processing Record 48 of Set 7 | puertollano
# Processing Record 49 of Set 7 | norman wells
# Processing Record 50 of Set 7 | nicolas bravo
# Processing Record 1 of Set 8 | mys shmidta
# City not found. Skipping...
# Processing Record 2 of Set 8 | kloulklubed
# Processing Record 3 of Set 8 | babol
# Processing Record 4 of Set 8 | selma
# Processing Record 5 of Set 8 | mareeba
# Processing Record 6 of Set 8 | singaparna
# Processing Record 7 of Set 8 | kavali
# Processing Record 8 of Set 8 | meyungs
# City not found. Skipping...
# Processing Record 9 of Set 8 | la crosse
# Processing Record 10 of Set 8 | kavaratti
# Processing Record 11 of Set 8 | shenjiamen
# Processing Record 12 of Set 8 | le mars
# Processing Record 13 of Set 8 | kupang
# Processing Record 14 of Set 8 | dwarka
# Processing Record 15 of Set 8 | namibe
# Processing Record 16 of Set 8 | tautira
# Processing Record 17 of Set 8 | nawabganj
# Processing Record 18 of Set 8 | marmande
# Processing Record 19 of Set 8 | tarko-sale
# Processing Record 20 of Set 8 | dong hoi
# Processing Record 21 of Set 8 | birao
# Processing Record 22 of Set 8 | abhar
# Processing Record 23 of Set 8 | svetlogorsk
# Processing Record 24 of Set 8 | san rafael
# Processing Record 25 of Set 8 | la primavera
# Processing Record 26 of Set 8 | san vicente
# Processing Record 27 of Set 8 | biltine
# Processing Record 28 of Set 8 | bokhan
# Processing Record 29 of Set 8 | mayo
# Processing Record 30 of Set 8 | gedo
# Processing Record 31 of Set 8 | anderson
# Processing Record 32 of Set 8 | vestmannaeyjar
# Processing Record 33 of Set 8 | fortuna
# Processing Record 34 of Set 8 | grand river south east
# City not found. Skipping...
# Processing Record 35 of Set 8 | ortona
# Processing Record 36 of Set 8 | kruisfontein
# Processing Record 37 of Set 8 | russell
# Processing Record 38 of Set 8 | maltahohe
# Processing Record 39 of Set 8 | villa bruzual
# Processing Record 40 of Set 8 | cap malheureux
# Processing Record 41 of Set 8 | hofn
# Processing Record 42 of Set 8 | aguadilla
# Processing Record 43 of Set 8 | kudahuvadhoo
# Processing Record 44 of Set 8 | tabulbah
# City not found. Skipping...
# Processing Record 45 of Set 8 | laguna
# Processing Record 46 of Set 8 | kieta
# Processing Record 47 of Set 8 | mujiayingzi
# Processing Record 48 of Set 8 | nizhniy kuranakh
# Processing Record 49 of Set 8 | murgab
# Processing Record 50 of Set 8 | gazni
# City not found. Skipping...
# Processing Record 1 of Set 9 | williams lake
# Processing Record 2 of Set 9 | esmeraldas
# Processing Record 3 of Set 9 | wasilla
# Processing Record 4 of Set 9 | palmer
# Processing Record 5 of Set 9 | thano bula khan
# City not found. Skipping...
# Processing Record 6 of Set 9 | lircay
# Processing Record 7 of Set 9 | cravo norte
# Processing Record 8 of Set 9 | tuy hoa
# Processing Record 9 of Set 9 | jambi
# Processing Record 10 of Set 9 | kinston
# Processing Record 11 of Set 9 | bilecik
# Processing Record 12 of Set 9 | grand gaube
# Processing Record 13 of Set 9 | bhindar
# Processing Record 14 of Set 9 | aitape
# Processing Record 15 of Set 9 | orapa
# Processing Record 16 of Set 9 | puerto colombia
# Processing Record 17 of Set 9 | dedougou
# Processing Record 18 of Set 9 | santa cruz
# Processing Record 19 of Set 9 | jiexiu
# Processing Record 20 of Set 9 | erattupetta
# Processing Record 21 of Set 9 | katsuura
# Processing Record 22 of Set 9 | surab
# Processing Record 23 of Set 9 | mahebourg
# Processing Record 24 of Set 9 | rincon
# Processing Record 25 of Set 9 | paranaiba
# Processing Record 26 of Set 9 | monrovia
# Processing Record 27 of Set 9 | grindavik
# Processing Record 28 of Set 9 | huilong
# Processing Record 29 of Set 9 | dao
# Processing Record 30 of Set 9 | mananara
# Processing Record 31 of Set 9 | pelym
# Processing Record 32 of Set 9 | byron bay
# Processing Record 33 of Set 9 | celles
# Processing Record 34 of Set 9 | naryan-mar
# Processing Record 35 of Set 9 | porto belo
# Processing Record 36 of Set 9 | atambua
# Processing Record 37 of Set 9 | sisimiut
# Processing Record 38 of Set 9 | manzhouli
# Processing Record 39 of Set 9 | wairoa
# Processing Record 40 of Set 9 | genhe
# Processing Record 41 of Set 9 | atar
# Processing Record 42 of Set 9 | havoysund
# Processing Record 43 of Set 9 | honnali
# Processing Record 44 of Set 9 | aykhal
# Processing Record 45 of Set 9 | fort saint james
# Processing Record 46 of Set 9 | klaksvik
# Processing Record 47 of Set 9 | myitkyina
# Processing Record 48 of Set 9 | dukat
# Processing Record 49 of Set 9 | gornyy
# Processing Record 50 of Set 9 | nisia floresta
# Processing Record 1 of Set 10 | broken hill
# Processing Record 2 of Set 10 | mount gambier
# Processing Record 3 of Set 10 | abu dhabi
# Processing Record 4 of Set 10 | rosarito
# Processing Record 5 of Set 10 | lardos
# Processing Record 6 of Set 10 | port-gentil
# Processing Record 7 of Set 10 | iqaluit
# Processing Record 8 of Set 10 | ostrovnoy
# Processing Record 9 of Set 10 | azimur
# City not found. Skipping...
# Processing Record 10 of Set 10 | bykovo
# Processing Record 11 of Set 10 | zhaoqing
# Processing Record 12 of Set 10 | mandalgovi
# Processing Record 13 of Set 10 | malia
# Processing Record 14 of Set 10 | marcona
# City not found. Skipping...
# Processing Record 15 of Set 10 | kasongo
# Processing Record 16 of Set 10 | lolua
# City not found. Skipping...
# Processing Record 17 of Set 10 | camalu
# Processing Record 18 of Set 10 | norfolk
# Processing Record 19 of Set 10 | mooi river
# City not found. Skipping...
# Processing Record 20 of Set 10 | hazleton
# Processing Record 21 of Set 10 | taltal
# Processing Record 22 of Set 10 | udachnyy
# Processing Record 23 of Set 10 | kalianget
# Processing Record 24 of Set 10 | dingle
# Processing Record 25 of Set 10 | shihezi
# Processing Record 26 of Set 10 | katangli
# Processing Record 27 of Set 10 | jiroft
# City not found. Skipping...
# Processing Record 28 of Set 10 | chippewa falls
# Processing Record 29 of Set 10 | barcelos
# Processing Record 30 of Set 10 | nueva loja
# Processing Record 31 of Set 10 | filingue
# Processing Record 32 of Set 10 | rongcheng
# Processing Record 33 of Set 10 | acapulco
# Processing Record 34 of Set 10 | oussouye
# Processing Record 35 of Set 10 | leh
# Processing Record 36 of Set 10 | svobodnyy
# Processing Record 37 of Set 10 | vila franca do campo
# Processing Record 38 of Set 10 | chara
# Processing Record 39 of Set 10 | gusau
# Processing Record 40 of Set 10 | luancheng
# Processing Record 41 of Set 10 | roma
# Processing Record 42 of Set 10 | clyde
# Processing Record 43 of Set 10 | comodoro rivadavia
# Processing Record 44 of Set 10 | roald
# Processing Record 45 of Set 10 | hornepayne
# Processing Record 46 of Set 10 | ndele
# Processing Record 47 of Set 10 | kindu
# Processing Record 48 of Set 10 | cap-aux-meules
# Processing Record 49 of Set 10 | sulurpeta
# City not found. Skipping...
# Processing Record 50 of Set 10 | talavera de la reina
# Processing Record 1 of Set 11 | kamenka
# Processing Record 2 of Set 11 | yeniseysk
# Processing Record 3 of Set 11 | aripuana
# Processing Record 4 of Set 11 | lumphat
# Processing Record 5 of Set 11 | linxia
# Processing Record 6 of Set 11 | rimini
# Processing Record 7 of Set 11 | la macarena
# Processing Record 8 of Set 11 | maragogi
# Processing Record 9 of Set 11 | xiaoshan
# Processing Record 10 of Set 11 | saint-germain-de-grantham
# Processing Record 11 of Set 11 | te anau
# Processing Record 12 of Set 11 | caravelas
# Processing Record 13 of Set 11 | arlit
# Processing Record 14 of Set 11 | yarmouth
# Processing Record 15 of Set 11 | pierre
# Processing Record 16 of Set 11 | colac
# Processing Record 17 of Set 11 | amapa
# Processing Record 18 of Set 11 | mayumba
# Processing Record 19 of Set 11 | mollendo
# Processing Record 20 of Set 11 | pathein
# Processing Record 21 of Set 11 | camacha
# Processing Record 22 of Set 11 | broome
# Processing Record 23 of Set 11 | belaya gora
# Processing Record 24 of Set 11 | nurota
# Processing Record 25 of Set 11 | mercedes
# Processing Record 26 of Set 11 | sidney
# Processing Record 27 of Set 11 | vidim
# Processing Record 28 of Set 11 | burgeo
# Processing Record 29 of Set 11 | chitaga
# Processing Record 30 of Set 11 | santa maria
# Processing Record 31 of Set 11 | qui nhon
# Processing Record 32 of Set 11 | narok
# Processing Record 33 of Set 11 | gornyak
# Processing Record 34 of Set 11 | tuatapere
# Processing Record 35 of Set 11 | salt
# Processing Record 36 of Set 11 | milford
# Processing Record 37 of Set 11 | seymchan
# Processing Record 38 of Set 11 | tiznit
# Processing Record 39 of Set 11 | sorrento
# Processing Record 40 of Set 11 | sambava
# Processing Record 41 of Set 11 | kattivakkam
# Processing Record 42 of Set 11 | lukovetskiy
# Processing Record 43 of Set 11 | moyale
# Processing Record 44 of Set 11 | rayong
# Processing Record 45 of Set 11 | nyurba
# Processing Record 46 of Set 11 | the pas
# Processing Record 47 of Set 11 | saint-leu
# Processing Record 48 of Set 11 | coihaique
# Processing Record 49 of Set 11 | sanghar
# Processing Record 50 of Set 11 | javanrud
# Processing Record 1 of Set 12 | tasbuget
# City not found. Skipping...
# Processing Record 2 of Set 12 | vinukonda
# Processing Record 3 of Set 12 | chernogolovka
# Processing Record 4 of Set 12 | sorland
# Processing Record 5 of Set 12 | tabou
# Processing Record 6 of Set 12 | aragats
# Processing Record 7 of Set 12 | meulaboh
# Processing Record 8 of Set 12 | crab hill
# City not found. Skipping...
# Processing Record 9 of Set 12 | port townsend
# Processing Record 10 of Set 12 | jiazi
# Processing Record 11 of Set 12 | sioux lookout
# Processing Record 12 of Set 12 | ngukurr
# City not found. Skipping...
# Processing Record 13 of Set 12 | bocas del toro
# Processing Record 14 of Set 12 | den helder
# Processing Record 15 of Set 12 | nipawin
# Processing Record 16 of Set 12 | zomba
# Processing Record 17 of Set 12 | yomou
# Processing Record 18 of Set 12 | kamaishi
# Processing Record 19 of Set 12 | new amsterdam
# Processing Record 20 of Set 12 | richards bay
# Processing Record 21 of Set 12 | mehamn
# Processing Record 22 of Set 12 | chake chake
# Processing Record 23 of Set 12 | fayaoue
# Processing Record 24 of Set 12 | pabrade
# Processing Record 25 of Set 12 | mangan
# Processing Record 26 of Set 12 | kurchum
# Processing Record 27 of Set 12 | poum
# Processing Record 28 of Set 12 | kittery
# Processing Record 29 of Set 12 | koppies
# Processing Record 30 of Set 12 | chekalin
# Processing Record 31 of Set 12 | octeville
# Processing Record 32 of Set 12 | gornopravdinsk
# Processing Record 33 of Set 12 | magadi
# Processing Record 34 of Set 12 | balaguer
# Processing Record 35 of Set 12 | necochea
# Processing Record 36 of Set 12 | skibbereen
# Processing Record 37 of Set 12 | walla walla
# Processing Record 38 of Set 12 | tucano
# Processing Record 39 of Set 12 | tabuk
# Processing Record 40 of Set 12 | belle fourche
# Processing Record 41 of Set 12 | razdolnoye
# Processing Record 42 of Set 12 | bambanglipuro
# Processing Record 43 of Set 12 | maneromango
# Processing Record 44 of Set 12 | itapuranga
# Processing Record 45 of Set 12 | sayat
# Processing Record 46 of Set 12 | kundiawa
# Processing Record 47 of Set 12 | ashtian
# Processing Record 48 of Set 12 | portland
# Processing Record 49 of Set 12 | hulan ergi
# Processing Record 50 of Set 12 | ambo
# Processing Record 1 of Set 13 | colares
# Processing Record 2 of Set 13 | nieuw amsterdam
# Processing Record 3 of Set 13 | bakchar
# Processing Record 4 of Set 13 | cururupu
# Processing Record 5 of Set 13 | samarai
# Processing Record 6 of Set 13 | abha
# Processing Record 7 of Set 13 | hensall
# Processing Record 8 of Set 13 | shimoda
# Processing Record 9 of Set 13 | yershov
# Processing Record 10 of Set 13 | richard toll
# City not found. Skipping...
# Processing Record 11 of Set 13 | san borja
# Processing Record 12 of Set 13 | uige
# Processing Record 13 of Set 13 | lubango
# Processing Record 14 of Set 13 | saint-felicien
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# 8. Add the data to a list in a dictionary format and then convert the list to a DataFrame.
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#          City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0      Baiyin  36.5583  104.2081     50.88        68           3        3.24
# 1      Dikson  73.5069   80.5464     35.56        99         100       10.04
# 2   Kisangani   0.5167   25.2000     71.51        90          71        2.26
# 3   Cape Town -33.9258   18.4232     65.12        82           0        3.44
# 4    Coquimbo -29.9533  -71.3436     60.53        58           0       16.11
# 5  Georgetown   5.4112  100.3354     79.90        78          20        0.00
# 6   Busselton -33.6500  115.3333     49.05        91           0        9.84
# 7   Balclutha -46.2339  169.7500     42.10        79           4        3.89
# 8       Conde  -7.2597  -34.9075     80.06        78           0        8.05
# 9        Hilo  19.7297 -155.0900     82.27        82          90        8.05
#
#   Country                 Date
# 0      CN  2021-09-22 20:17:03
# 1      RU  2021-09-22 20:17:04
# 2      CD  2021-09-22 20:17:04
# 3      ZA  2021-09-22 20:17:04
# 4      CL  2021-09-22 20:17:05
# 5      MY  2021-09-22 20:13:49
# 6      AU  2021-09-22 20:17:05
# 7      NZ  2021-09-22 20:17:05
# 8      BR  2021-09-22 20:17:06
# 9      US  2021-09-22 20:17:06

# %%
city_data_reorder = ["City", "Country", "Date", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed"]
city_data_df=city_data_df[city_data_reorder]

city_data_df.head()
# Out:
#         City Country                 Date      Lat       Lng  Max Temp  \
# 0     Baiyin      CN  2021-09-22 20:17:03  36.5583  104.2081     50.88
# 1     Dikson      RU  2021-09-22 20:17:04  73.5069   80.5464     35.56
# 2  Kisangani      CD  2021-09-22 20:17:04   0.5167   25.2000     71.51
# 3  Cape Town      ZA  2021-09-22 20:17:04 -33.9258   18.4232     65.12
# 4   Coquimbo      CL  2021-09-22 20:17:05 -29.9533  -71.3436     60.53
#
#    Humidity  Cloudiness  Wind Speed
# 0        68           3        3.24
# 1        99         100       10.04
# 2        90          71        2.26
# 3        82           0        3.44
# 4        58           0       16.11

# %%
# Create the output file (CSV).
output_data_file = "weather_data/cities.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")

# %%
# Extract relevant fields from the DF for plotting
lats = city_data_df["Lat"]
max_temps = city_data_df["Max Temp"]
humidity = city_data_df["Humidity"]
cloudiness = city_data_df["Cloudiness"]
wind_speed = city_data_df["Wind Speed"]

# %%
# import time module
import time

# build the scatter plot for latitude vs max temp
plt.scatter(lats,
           max_temps,
           edgecolor="black", linewidths=1, marker="o",
           alpha=0.8, label="Cities")

# Incorporate the other graph properties
plt.title(f"City Latitiude vs. Max Temp" + time.strftime(" %x"))
plt.ylabel("Max Temp (F)")
plt.xlabel("Latitude")
plt.grid(True)

# save the figure
plt.savefig("weather_data/Flig1.png")

# show plot
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
# build the scatter plots for lat vs humidity
plt.scatter(lats,
           humidity,
           edgecolor="black", linewidths=1, marker="o",
           alpha=0.8, label="Cities")

# incorporate the other graph properties
plt.title(f"City Latitude vs Humidity" + time.strftime(" %x"))
plt.ylabel("Humidity(%)")
plt.xlabel("Latitude")
plt.grid(True)
# save fig
plt.savefig("weather_data/Fig2.png")
# show plot
plt.show()

# %%
# build scatter plots for lat vs cloudiness
plt.scatter(lats,
           cloudiness,
           edgecolor="black", linewidths=1, marker="o",
           alpha=0.8, label="Cities")

# incorporate other graph properties
plt.title(f"City Latitude vs Cloudiness (%)" + time.strftime(" %x"))
plt.ylabel("Cloudiness (%)")
plt.xlabel("Latitude")
plt.grid(True)
# save the figure
plt.savefig("weather_data/Fig3.png")
#show plot
plt.show()

# %%
# Build the scatter plots for latitude vs. wind speed.
plt.scatter(lats,
            wind_speed,
            edgecolor="black", linewidths=1, marker="o",
            alpha=0.8, label="Cities")

# Incorporate the other graph properties.
plt.title(f"City Latitude vs. Wind Speed "+ time.strftime("%x"))
plt.ylabel("Wind Speed (mph)")
plt.xlabel("Latitude")
plt.grid(True)
# Save the figure.
plt.savefig("weather_data/Fig4.png")
# Show plot.
plt.show()
